# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from datetime import datetime

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

from tqdm import tqdm_notebook
from pprint import pprint

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_lat = []
city_long = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        city_lat.append(lat_lng[0])
        city_long.append(lat_lng[1])

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
c= "London"
query_url = f"{base_url}appid={api_key}&q={c}&units={units}"
response1 = requests.get(query_url).json()
# pprint(response1)

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

## Lists to store information once loop runs
city_list = []
cloud_list = []
country_list = []
date_list = []
humid_list = []
lat_list = []
long_list = []
temp_list = []
wind_list = []

r=1
s=1

print('Beginning Data Retrieval')
print('-----------------------------')

for c in cities:
    query_url = f"{base_url}appid={api_key}&q={c}&units={units}"
    response = requests.get(query_url).json()

    try:  
        Name = response["name"]
        Cloudiness = response["clouds"]["all"]
        Country = response["sys"]["country"]
        Date = response["dt"]
        Humidity = response["main"]["humidity"]
        Latitude = response["coord"]["lat"]
        Longitude = response["coord"]["lon"]
        Temperature = response["main"]["temp_max"]
        WindSpeed = response["wind"]["speed"]

        city_list.append(Name)
        cloud_list.append(Cloudiness)
        country_list.append(Country)
        date_list.append(Date)
        humid_list.append(Humidity)
        lat_list.append(Latitude)
        long_list.append(Longitude)
        temp_list.append(Temperature)
        wind_list.append(WindSpeed)
        print(f"Processing Record {r} of Set {s} | {Name}")
        r+=1
    except KeyError:
        city_list.append('NaN')
        cloud_list.append('NaN')
        country_list.append('NaN')
        date_list.append('NaN')
        humid_list.append('NaN')
        lat_list.append('NaN')
        long_list.append('NaN')
        temp_list.append('NaN')
        wind_list.append('NaN')
        print('City not found. Skipping...')
    if r == 11:
        r=1
        s+=1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Punta Arenas
# City not found. Skipping...
# Processing Record 2 of Set 1 | San Lorenzo
# Processing Record 3 of Set 1 | Port Blair
# City not found. Skipping...
# Processing Record 4 of Set 1 | San Vicente
# Processing Record 5 of Set 1 | Vaini
# Processing Record 6 of Set 1 | Ulety
# Processing Record 7 of Set 1 | Ushuaia
# Processing Record 8 of Set 1 | Rocha
# Processing Record 9 of Set 1 | Danville
# Processing Record 10 of Set 1 | San Rafael del Sur
# Processing Record 1 of Set 2 | Oksfjord
# Processing Record 2 of Set 2 | New Norfolk
# Processing Record 3 of Set 2 | Provideniya
# Processing Record 4 of Set 2 | Busselton
# Processing Record 5 of Set 2 | Nichinan
# City not found. Skipping...
# Processing Record 6 of Set 2 | Kihei
# City not found. Skipping...
# Processing Record 7 of Set 2 | Mataura
# Processing Record 8 of Set 2 | Bredasdorp
# Processing Record 9 of Set 2 | Sao Mateus do Maranhao
# Processing Record 10 of Set 2 | Tuktoyaktuk
# Processing Record 1 of Set 3 | Gat
# Processing Record 2 of Set 3 | Bethel
# Processing Record 3 of Set 3 | Talisayan
# Processing Record 4 of Set 3 | Hilo
# Processing Record 5 of Set 3 | Harper
# Processing Record 6 of Set 3 | Kruisfontein
# Processing Record 7 of Set 3 | Champasak
# Processing Record 8 of Set 3 | Pisco
# Processing Record 9 of Set 3 | Castro
# Processing Record 10 of Set 3 | Upernavik
# Processing Record 1 of Set 4 | East London
# Processing Record 2 of Set 4 | Amarastii de Jos
# City not found. Skipping...
# Processing Record 3 of Set 4 | Barrow
# Processing Record 4 of Set 4 | Puerto Ayora
# Processing Record 5 of Set 4 | Laguna
# Processing Record 6 of Set 4 | Khatanga
# Processing Record 7 of Set 4 | Mentakab
# Processing Record 8 of Set 4 | Yellowknife
# Processing Record 9 of Set 4 | Kapaa
# Processing Record 10 of Set 4 | Havelock
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set
# Processing Record 1 of Set 11 | Bridlington
# Processing Record 2 of Set 11 | Pathein
# Processing Record 3 of Set 11 | Clyde River
# Processing Record 4 of Set 11 | Lebu
# Processing Record 5 of Set 11 | Avarua
# Processing Record 6 of Set 11 | Tabuk
# Processing Record 7 of Set 11 | Mirnyy
# Processing Record 8 of Set 11 | Kijang
# Processing Record 9 of Set 11 | Bonnyville
# Processing Record 10 of Set 11 | Arteaga
# Processing Record 1 of Set 12 | Tubmanburg
# Processing Record 2 of Set 12 | Norman Wells
# City not found. Skipping...
# Processing Record 3 of Set 12 | Fayaoue
# Processing Record 4 of Set 12 | Hithadhoo
# Processing Record 5 of Set 12 | Viransehir
# Processing Record 6 of Set 12 | La Asuncion
# Processing Record 7 of Set 12 | Praia
# Processing Record 8 of Set 12 | La Ronge
# Processing Record 9 of Set 12 | Carnarvon
# Processing Record 10 of Set 12 | Airai
# Processing Record 1 of Set 13 | High Level
# Processing Record 2 of Set 13 | Sungaipenuh
# Processing Record 3 of Set 13 | Port Augusta
# Processing Record 4 of Set 13 | Iquique
# Processing Record 5 of Set 13 | Gillette
# Processing Record 6 of Set 13 | Tiksi
# Processing Record 7 of Set 13 | Catio
# Processing Record 8 of Set 13 | Mugumu
# Processing Record 9 of Set 13 | Inuvik
# Processing Record 10 of Set 13 | Talnakh
# Processing Record 1 of Set 14 | Poum
# Processing Record 2 of Set 14 | Eureka
# Processing Record 3 of Set 14 | Gigmoto
# Processing Record 4 of Set 14 | Payo
# Processing Record 5 of Set 14 | Namatanai
# Processing Record 6 of Set 14 | Sitka
# Processing Record 7 of Set 14 | Grindavik
# Processing Record 8 of Set 14 | Geraldton
# Processing Record 9 of Set 14 | Buta
# Processing Record 10 of Set 14 | Ayan
# Processing Record 1 of Set 15 | Ingham
# City not found. Skipping...
# Processing Record 2 of Set 15 | Kananga
# Processing Record 3 of Set 15 | Nikolskoye
# City not found. Skipping...
# Processing Record 4 of Set 15 | Skelleftea
# Processing Record 5 of Set 15 | Lazaro Cardenas
# Processing Record 6 of Set 15 | Ostrovnoy
# Processing Record 7 of Set 15 | Arraial do Cabo
# Processing Record 8 of Set 15 | Kondrovo
# Processing Record 9 of Set 15 | Half Moon Bay
# Processing Record 10 of Set 15 | Sobolevo
# Processing Record 1 of Set 16 | Umm Lajj
# Processing Record 2 of Set 16 | Bam
# Processing Record 3 of Set 16 | Qaanaaq
# Processing Record 4 of Set 16 | Bonthe
# Processing Record 5 of Set 16 | Zhanaozen
# Processing Record 6 of Set 16 | Bressuire
# Processing Record 7 of Set 16 | Beringovskiy
# Processing Record 8 of Set 16 | Aberdeen
# Processing Record 9 of Set 16 | Hornepayne
# Processing Record 10 of Set 16 | Yulara
# Processing Record 1 of Set 17 | Ningxiang
# Processing Record 2 of Set 17 | Yumen
# Processing Record 3 of Set 17 | Torbay
# Processing Record 4 of Set 17 | Saint-Joseph
# Processing Record 5 of Set 17 | Mar del Plata
# Processing Record 6 of Set 17 | Dhidhdhoo
# Processing Record 7 of Set 17 | Sechura
# Processing Record 8 of Set 17 | Nome
# Processing Record 4 of Set 44 | Aranos
# Processing Record 5 of Set 44 | Longyearbyen
# Processing Record 6 of Set 44 | Todos Santos
# Processing Record 7 of Set 44 | Jijiga
# Processing Record 8 of Set 44 | Falmouth
# Processing Record 9 of Set 44 | Biak
# Processing Record 10 of Set 44 | Tura
# Processing Record 1 of Set 45 | Neiafu
# Processing Record 2 of Set 45 | Nago
# Processing Record 3 of Set 45 | Almora
# Processing Record 4 of Set 45 | Sikasso
# Processing Record 5 of Set 45 | Port Hardy
# Processing Record 6 of Set 45 | Hovd
# Processing Record 7 of Set 45 | Kamaishi
# Processing Record 8 of Set 45 | Seoul
# Processing Record 9 of Set 45 | Archidona
# Processing Record 10 of Set 45 | Alto Paraguai
# Processing Record 1 of Set 46 | Cap Malheureux
# City not found. Skipping...
# Processing Record 2 of Set 46 | Ulladulla
# Processing Record 3 of Set 46 | Epinal
# City not found. Skipping...
# Processing Record 4 of Set 46 | Mayo
# Processing Record 5 of Set 46 | Mountain Home
# Processing Record 6 of Set 46 | Vilyuysk
# Processing Record 7 of Set 46 | Qasigiannguit
# Processing Record 8 of Set 46 | Catuday
# Processing Record 9 of Set 46 | Egvekinot
# Processing Record 10 of Set 46 | Bom Jesus da Lapa
# Processing Record 1 of Set 47 | Fortuna
# Processing Record 2 of Set 47 | Salinopolis
# Processing Record 3 of Set 47 | Kaeo
# Processing Record 4 of Set 47 | Nizhniy Kuranakh
# Processing Record 5 of Set 47 | Puerto Baquerizo Moreno
# Processing Record 6 of Set 47 | Krasnozatonskiy
# Processing Record 7 of Set 47 | Simao
# Processing Record 8 of Set 47 | Icoana
# Processing Record 9 of Set 47 | Barcelos
# Processing Record 10 of Set 47 | Rabo de Peixe
# Processing Record 1 of Set 48 | Celestun
# Processing Record 2 of Set 48 | Murashi
# Processing Record 3 of Set 48 | Rorvik
# Processing Record 4 of Set 48 | Ola
# Processing Record 5 of Set 48 | Duku
# Processing Record 6 of Set 48 | Salalah
# Processing Record 7 of Set 48 | Ipixuna
# Processing Record 8 of Set 48 | Norsup
# Processing Record 9 of Set 48 | Los Llanos de Aridane
# Processing Record 10 of Set 48 | Natal
# Processing Record 1 of Set 49 | Pocatello
# Processing Record 2 of Set 49 | Ochakiv
# Processing Record 3 of Set 49 | Acari
# Processing Record 4 of Set 49 | Quatre Cocos
# Processing Record 5 of Set 49 | Codrington
# Processing Record 6 of Set 49 | Leh
# Processing Record 7 of Set 49 | Namibe
# Processing Record 8 of Set 49 | Taoudenni
# Processing Record 9 of Set 49 | Raton
# City not found. Skipping...
# Processing Record 10 of Set 49 | Alugan
# Processing Record 1 of Set 50 | Mitu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 50 | Presidencia Roque Saenz Pena
# Processing Record 3 of Set 50 | Evans
# Processing Record 4 of Set 50 | Novopavlovka
# Processing Record 5 of Set 50 | Matadi
# Processing Record 6 of Set 50 | Gornji Milanovac
# Processing Record 7 of Set 50 | Vladivostok
# Processing Record 8 of Set 50 | Voh
# Processing Record 9 of Set 50 | Tezu
# City not found. Skipping...
# Processing Record 7 of Set 57 | Changping
# Processing Record 8 of Set 57 | Mamlyutka
# Processing Record 9 of Set 57 | Torres
# Processing Record 10 of Set 57 | Hanna
# Processing Record 1 of Set 58 | Kushiro

# %%
## Create initial weather data frame from lists
weather_df = pd.DataFrame({"City" : city_list,
              "Cloudiness" : cloud_list,
              "Country" : country_list,
              "Date" : date_list,
              "Humidity" : humid_list,
              "Lat" : lat_list,
              "Lng" : long_list,
             "Max Temp" : temp_list,
             "Wind Speed" : wind_list})
weather_df.head()

# Output File (CSV)
output_data_file = "output_data/cities.csv"
weather_df.to_csv(output_data_file, encoding='utf-8')

# %%
## Remove cities with no values
weather_clean = weather_df[~weather_df.City.str.contains("NaN")]
weather_clean.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat    Lng  \
# 0  Punta Arenas          0      CL  1563849553       65 -53.16 -70.91
# 2   San Lorenzo        100      HN  1563849553       58  13.43 -87.45
# 3    Port Blair         70      IN  1563849553       79  11.67  92.75
# 5   San Vicente         40      EC  1563849553       83  -0.59 -80.41
# 6         Vaini         75      IN  1563849554       94  15.34  74.49
#
#   Max Temp Wind Speed
# 0     33.8      25.28
# 2    79.06       2.77
# 3    83.56      20.36
# 5     73.4        4.7
# 6     71.6       9.17

# %%
## Convert object columns to numbers
weather_clean[["Cloudiness", "Date","Humidity","Lat","Lng","Max Temp",
               "Wind Speed"]] = weather_clean[["Cloudiness", "Date",
                                               "Humidity","Lat","Lng","Max Temp",
                                               "Wind Speed"]].apply(pd.to_numeric)
weather_clean.dtypes
# Out:
# City           object
# Cloudiness      int64
# Country        object
# Date            int64
# Humidity        int64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
## Time stamp current date
c_time = pd.to_datetime(datetime.now()).strftime('%Y-%m-%d')

# %%
plot1 = weather_clean.plot.scatter(x='Lat',y='Max Temp', c='DarkBlue',alpha=0.5,
                                  edgecolors="black",
                                   title=f"City Latitude vs. Max Temp ({c_time})")
plot1.set_xlabel("Latitude")
plot1.set_ylabel("Maximum Temperature (F)")
plot1.grid()

plt.savefig('Images/LatVsTemp.png')

# %%
plot2 = weather_clean.plot.scatter(x='Lat',y='Humidity', c='DarkBlue',alpha=0.5,
                                  edgecolors="black",
                                   title=f"City Latitude vs. Humidity ({c_time})")
plot2.set_xlabel("Latitude")
plot2.set_ylabel("Humidity (%)")
plot2.grid()

plt.savefig('Images/LatVsHumidity.png')

# %%
plot3 = weather_clean.plot.scatter(x='Lat',y='Cloudiness', c='DarkBlue',alpha=0.5,
                                  edgecolors="black",
                                   title=f"City Latitude vs. Cloudiness ({c_time})")
plot3.set_xlabel("Latitude")
plot3.set_ylabel("Cloudiness (%)")
plot3.grid()

plt.savefig('Images/LatVsClouds.png')

# %%
plot4 = weather_clean.plot.scatter(x='Lat',y='Wind Speed', c='DarkBlue',alpha=0.5,
                                  edgecolors="black",
                                   title=f"City Latitude vs. Wind Speed ({c_time})")
plot4.set_xlabel("Latitude")
plot4.set_ylabel("Wind Speed (mph)")
plot4.grid()

plt.savefig('Images/LatVsWind.png')
